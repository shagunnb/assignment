# %%
    # Question 1

# Method 1: Using np.array()
array1 = np.array([[1, 2, 3], [4, 5, 6]])
print("Method 1: Using np.array()")
print(array1)
# Output
Method 1: Using np.array()
[[1 2 3]
 [4 5 6]]

# Method 2: Using np.zeros()
array2 = np.zeros((2, 3), dtype=int)  # Create a 2x3 array of zeros
array2[0] = [1, 2, 3]  # Assign first row
array2[1] = [4, 5, 6]  # Assign second row
print("\nMethod 2: Using np.zeros()")
print(array2)
# Output
Method 2: Using np.zeros()
[[1 2 3]
 [4 5 6]]

# Method 3: Using np.arange() and reshape()
array3 = np.arange(1, 7).reshape(2, 3)  # Create an array from 1 to 6 and reshape to 2x3
print("\nMethod 3: Using np.arange() and reshape()")
print(array3)
# Output
Method 3: Using np.arange() and reshape()
[[1 2 3]
 [4 5 6]]

# Question 2
import numpy as np

# Define the parameters
w = 10         # Starting value
wR = 50       # Ending value
numPers = 12   # Number of points to generate

# Generate an array of evenly spaced numbers
array_1d = np.linspace(w, wR, numPers)

# Reshape the array into a 2D array (e.g., 3 rows and 4 columns)
array_2d = array_1d.reshape(3, 4)  # Adjust dimensions based on numPers

print("1D Array of Evenly Spaced Numbers:")
print(array_1d)

print("\n2D Array Reshaped:")
print(array_2d)


# Question 4
import numpy as np

# Parameters
x = 10  # Specify the size of the array
low = 0.0  # Lower bound
high = 2.0  # Upper bound

# Generate a 1D array with random floating-point numbers between 0 and 2
random_array = np.random.uniform(low, high, size=x)
print("Random Array (before rounding):")
print(random_array)

# Round each number in the array to 2 decimal places
rounded_array = np.round(random_array, 2)
print("\nRounded Array (to 2 decimal places):")
print(rounded_array)


# Question 5
import numpy as np

# Define parameters
w = 10  # Lower bound
wR = 50  # Upper bound
shape = (5, 6)  # Shape of the array (5 rows, 6 columns)

# Create a NumPy array with random integers between w and wR
random_array = np.random.randint(w, wR + 1, size=shape)
print("Random Array:")
print(random_array)

# a) Extract all even integers from the array
even_integers = random_array[random_array % 2 == 0]
print("\nEven Integers:")
print(even_integers)

# b) Extract all odd integers from the array
odd_integers = random_array[random_array % 2 != 0]
print("\nOdd Integers:")
print(odd_integers)

# Question 6
import numpy as np

# Define parameters
w = 10  # Lower bound
wR = 50  # Upper bound
shape = (4, 3, 5)  # Shape of the array (4x3x5)

# Create a 3D NumPy array with random integers between w and wR
random_array = np.random.randint(w, wR + 1, size=shape)
print("Random 3D Array:")
print(random_array)

# a) Find the indices of the maximum values along each depth level (third axis)
max_indices = np.argmax(random_array, axis=2)
print("\nIndices of Maximum Values along Each Depth Level:")
print(max_indices)

# b) Perform element-wise multiplication of the array with itself
elementwise_multiplication = random_array * random_array
print("\nElement-wise Multiplication of the Array:")
print(elementwise_multiplication)

# Question 7
import pandas as pd

# Sample dataset
data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Phone': ['+1 (123) 456-7890', '123-456-7890', '(987) 654-3210'],
    'Age': [25, 30, 35]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display original DataFrame
print("Original DataFrame:")
print(df)

# Clean and transform the 'Phone' column
df['Phone'] = df['Phone'].replace(r'\D', '', regex=True).astype(float)

# Display the cleaned DataFrame
print("\nCleaned DataFrame:")
print(df)

# Display DataFrame attributes and data types of each column
print("\nDataFrame Attributes and Data Types:")
print(df.dtypes)

# Question 8
import pandas as pd

# a) Read the 'data.csv' file, skipping the first 50 rows
file_path = 'data.csv'  # Update this path to your actual file location
df = pd.read_csv(file_path, skiprows=50)

# b) Only read the specified columns
filtered_columns = ['Last Name', 'Gender', 'Email', 'Phone', 'Salary']
filtered_df = df[filtered_columns]

# c) Display the first 10 rows of the filtered dataset
print("First 10 rows of the filtered dataset:")
print(filtered_df.head(10))

# d) Extract the 'Salary' column as a Series and display its last 5 values
salary_series = filtered_df['Salary']
print("\nLast 5 values of the 'Salary' column:")
print(salary_series.tail(5))

# Question 9
import pandas as pd

# Read the 'People_Dataset.csv' file
file_path = 'People_Dataset.csv'  # Update this path to your actual file location
df = pd.read_csv(file_path)

# Define the filter conditions
last_name_condition = df['Last Name'].str.contains('Due', na=False)
gender_condition = df['Gender'].str.contains('Female', na=False)
salary_condition = df['Salary'] < 40000  # Replace 40000 with your specified salary limit

# Apply the filters
filtered_df = df[last_name_condition & gender_condition & salary_condition]

# Display the filtered dataset
print("Filtered Dataset:")
print(filtered_df)

# Question 10
import pandas as pd
import numpy as np

# Define parameters
num_integers = 35  # Total number of random integers
lower_bound = 1    # Lower bound (inclusive)
upper_bound = 6    # Upper bound (inclusive)

# Generate a Series with 35 random integers between 1 and 6
random_series = pd.Series(np.random.randint(lower_bound, upper_bound + 1, size=num_integers))

# Create a 7x5 DataFrame from the Series
dataframe = random_series.values.reshape(7, 5)

# Convert the reshaped array into a DataFrame
df = pd.DataFrame(dataframe, columns=[f'Column {i+1}' for i in range(5)])

# Display the DataFrame
print("7x5 DataFrame:")
print(df)

# Question 11
import pandas as pd
import numpy as np

# a) Create the first Series with random numbers ranging from 10 to 50
series1 = pd.Series(np.random.randint(10, 51, size=50))

# b) Create the second Series with random numbers ranging from 100 to 1000
series2 = pd.Series(np.random.randint(100, 1001, size=50))

# c) Create a DataFrame by joining these Series by column
df = pd.DataFrame({'col1': series1, 'col2': series2})

# Display the DataFrame
print("Combined DataFrame:")
print(df)

# Question 12
import pandas as pd

# Load the dataset (update the file path to your actual dataset)
file_path = 'people_dataset.csv'  # Replace with your actual file name
df = pd.read_csv(file_path)

# Display the original DataFrame
print("Original DataFrame:")
print(df)

# a) Delete the 'Email', 'Phone', and 'Date of birth' columns
df.drop(columns=['Email', 'Phone', 'Date of birth'], inplace=True)

# b) Delete the rows containing any missing values
df.dropna(inplace=True)

# d) Print the final output
print("\nFinal DataFrame after deletions:")
print(df)

# Question 13
import numpy as np
import matplotlib.pyplot as plt

# Create two NumPy arrays, x and y, each containing 100 random float values between 0 and 1
x = np.random.rand(100)
y = np.random.rand(100)

# a) Create a scatter plot
plt.scatter(x, y, color='red', marker='o', label='Data Points')

# b) Add a horizontal line at y = 0.5
plt.axhline(y=0.5, color='blue', linestyle='--', label='y = 0.5')

# c) Add a vertical line at x = 0.5
plt.axvline(x=0.5, color='green', linestyle=':', label='x = 0.5')

# d) Label the axes
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# e) S

# Question 14
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Create a time-series dataset
dates = pd.date_range(start='2023-01-01', periods=100, freq='D')
temperature = np.random.uniform(low=15, high=30, size=100)  # Random temperatures between 15 and 30
humidity = np.random.uniform(low=30, high=80, size=100)     # Random humidity between 30% and 80%

# Create the DataFrame
data = pd.DataFrame({
    'Date': dates,
    'Temperature': temperature,
    'Humidity': humidity
})

# a) Plot the 'Temperature' and 'Humidity' on the same plot with different y-axes
fig, ax1 = plt.subplots()

# Plot Temperature
ax1.plot(data['Date'], data['Temperature'], color='tab:red', label='Temp

# Question 15
